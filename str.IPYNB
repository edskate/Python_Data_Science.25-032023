# %%
a = 10
b = 20
c = 'python é '
d = 'legal'

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# str

# %%
a + b
# Out:
# 30

# %%
c + d
# Out:
# 'python é legal'

# %%
# c + a
